# %%
import numpy as np
import pandas as pd
import os

# %%
# !git config --global user.email 'yl3336@cornell.edu'
# !git config --global user.name 'yirann2000

#Make a clone of github REPO
pat = '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'
! git clone https://{pat}@github.com/PhilippeMoesch/Datathon23.git

# %%
#Copy file from either google drive after mounting using file browser
# !cp /content/drive/MyDrive/Colab Notebooks/datathon_code /content/Datathon23
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/datathon_code': No such file or directory

# %%
! git add load_data.ipynb
! git commit -m 'trying to see if I can push successfully from google colab'  # commit in Colab
! git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
data_wd = '/content/drive/MyDrive/train/train'

# %%
dt_main = pd.read_csv(os.path.join(wd, 'main.csv'))
dt_freq = pd.read_csv(os.path.join(wd, 'frequency.csv'), engine='python')

# %%
dt_indt = pd.read_csv(os.path.join(wd, 'indicator.csv'), engine='python')

# %%
dt_freq.head()
# Out:
#                           ts      va
# 0  2022-06-23 00:00:00+02:00  50.024
# 1  2022-06-23 00:00:01+02:00  50.024
# 2  2022-06-23 00:00:02+02:00  50.032
# 3  2022-06-23 00:00:03+02:00  50.032
# 4  2022-06-23 00:00:04+02:00  50.032

# %%
dt_main.head()
# Out:
#                           ts  solar  wind_offshore  wind_onshore  \
# 0  2022-06-23 00:00:00+02:00    0.0          105.0        5231.0
# 1  2022-06-23 00:15:00+02:00    0.0           86.0        5045.0
# 2  2022-06-23 00:30:00+02:00    0.0           81.0        4864.0
# 3  2022-06-23 00:45:00+02:00    0.0           81.0        4628.0
# 4  2022-06-23 01:00:00+02:00    0.0           87.0        4459.0
#
#    forecast_solar  forecast_wind_offshore  forecast_wind_onshore  \
# 0             0.0                    96.0                 5497.0
# 1             0.0                    84.0                 5099.0
# 2             0.0                    79.0                 4953.0
# 3             0.0                    78.0                 4798.0
# 4             0.0                    84.0                 4651.0
#
#    forecast_consumption  consumption_actual  prl_up  prl_down  afrr_up  \
# 0               47138.0             46434.0  82.040     0.775   63.649
# ...
